# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Reading dataset
data = pd.read_csv("enron_data_file.csv")
data
# Out:
#      Unnamed: 0                 names    salary  to_messages  \
# 0             0            METTS MARK  365788.0        807.0
# 1             1         BAXTER JOHN C  267102.0          0.0
# 2             2        ELLIOTT STEVEN  170941.0          0.0
# 3             3      CORDES WILLIAM R       0.0        764.0
# 4             4        HANNON KEVIN P  243293.0       1045.0
# ..          ...                   ...       ...          ...
# 141         141         GRAMM WENDY L       0.0          0.0
# 142         142      CAUSEY RICHARD A  415189.0       1892.0
# 143         143     TAYLOR MITCHELL S  265214.0        533.0
# 144         144  DONAHUE JR JEFFREY M  278601.0        865.0
# 145         145       GLISAN JR BEN F  274975.0        873.0
#
#      deferral_payments  total_payments  loan_advances      bonus  \
# 0                  0.0       1061827.0            0.0   600000.0
# 1            1295738.0       5634343.0            0.0  1200000.0
# ...

# %%
data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
#s = data[data['poi']==1].names

# %%
sns.histplot(data['loan_advances']) 
plt.show()
sns.distplot(data['total_payments']) 
plt.show()

sns.histplot(data['restricted_stock_deferred']) 
plt.show()
# Out:
# C:\Users\Himanshu Rajpoot\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 data.hist(bins=10,figsize =(10,14))
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'to_messages'}>,
#         <AxesSubplot:title={'center':'deferral_payments'}>,
#         <AxesSubplot:title={'center':'total_payments'}>],
#        [<AxesSubplot:title={'center':'loan_advances'}>,
#         <AxesSubplot:title={'center':'bonus'}>,
#         <AxesSubplot:title={'center':'restricted_stock_deferred'}>,
#         <AxesSubplot:title={'center':'deferred_income'}>],
#        [<AxesSubplot:title={'center':'total_stock_value'}>,
#         <AxesSubplot:title={'center':'expenses'}>,
#         <AxesSubplot:title={'center':'from_poi_to_this_person'}>,
#         <AxesSubplot:title={'center':'exercised_stock_options'}>],
#        [<AxesSubplot:title={'center':'from_messages'}>,
#         <AxesSubplot:title={'center':'other'}>,
#         <AxesSubplot:title={'center':'from_this_person_to_poi'}>,
#         <AxesSubplot:title={'center':'long_term_incentive'}>],
# ...

# %%
data.boxplot(column =['salary'])
plt.show()
print(data["salary"].sort_values())
#last value is very large which is total sum
data.loc[103]
# Out:
# 132           0.0
# 35            0.0
# 37            0.0
# 38            0.0
# 39            0.0
#           ...
# 116      655037.0
# 128     1060932.0
# 64      1072321.0
# 95      1111258.0
# 103    26704229.0
# Name: salary, Length: 146, dtype: float64
# names                              TOTAL
# salary                       2.67042e+07
# to_messages                            0
# deferral_payments            3.20834e+07
# total_payments               3.09887e+08
# loan_advances                 8.3925e+07
# bonus                        9.73436e+07
# restricted_stock_deferred   -7.57679e+06
# deferred_income             -2.79929e+07
# total_stock_value             4.3451e+08
# expenses                      5.2352e+06
# from_poi_to_this_person                0
# exercised_stock_options      3.11764e+08
# from_messages                          0
# other                        4.26676e+07
# from_this_person_to_poi                0
# long_term_incentive          4.85219e+07
# ...

# %%
#making Total = 0
data2 = data.copy()
data2.at[103,:] = 0
data2.boxplot(column =['salary'])
plt.show()
set0=data2[data2['salary']>1000000].names
set0
#Outliers in salary// Potential POI:LAY KENNETH L, SKILLING JEFFREY K, FREVERT MARK A
# Out:
# 64          LAY KENNETH L
# 95     SKILLING JEFFREY K
# 128        FREVERT MARK A
# Name: names, dtype: object

# %%
data2.boxplot(column =['from_messages'])
print(data2['from_messages'].sort_values())
set5 = data2[data2['from_messages']>2000].names
set5
# Out:
# 44         0.0
# 60         0.0
# 100        0.0
# 103        0.0
# 55         0.0
#         ...
# 57      2742.0
# 59      3069.0
# 32      4343.0
# 102     6759.0
# 89     14368.0
# Name: from_messages, Length: 146, dtype: float64
# 25      SHANKMAN JEFFREY A
# 32            BECK SALLY W
# 42         LAVORATO JOHN J
# 57     MCCONNELL MICHAEL S
# 59        DELAINEY DAVID W
# 89     KAMINSKI WINCENTY J
# 102          KEAN STEVEN J
# 108        ALLEN PHILLIP K
# Name: names, dtype: object

# %%
data2.boxplot(column =['to_messages'])
print(data2['to_messages'].sort_values())
set1=data2[data2['to_messages']>4000].names
print(set1)
#most mails /// 'BECK SALLY W', 'KAMINSKI WINCENTY J', 'KEAN STEVEN J', 'LAVORATO JOHN J'//
                                                                        ##highest mail sent and received: 'KEAN STEVEN J'
setMsg = set(set1).intersection(set(set5))
setMsg
# Out:
# 92         0.0
# 70         0.0
# 37         0.0
# 120        0.0
# 100        0.0
#         ...
# 32      7315.0
# 81      7991.0
# 22      8305.0
# 102    12754.0
# 50     15149.0
# Name: to_messages, Length: 146, dtype: float64
# 8          HAEDICKE MARK E
# 22          KITCHEN LOUISE
# 32            BECK SALLY W
# 42         LAVORATO JOHN J
# 50       SHAPIRO RICHARD S
# 56      WHALLEY LAWRENCE G
# 64           LAY KENNETH L
# 81        BELDEN TIMOTHY N
# 89     KAMINSKI WINCENTY J
# 102          KEAN STEVEN J
# Name: names, dtype: object
# {'BECK SALLY W', 'KAMINSKI WINCENTY J', 'KEAN STEVEN J', 'LAVORATO JOHN J'}

# %%
data2.boxplot(column =['bonus'])
print(data2['bonus'].sort_values())
set2 = data2[data2['bonus']>2000000].names
print(set2)
# Out:
# 46           0.0
# 63           0.0
# 61           0.0
# 111          0.0
# 58           0.0
#          ...
# 108    4175000.0
# 81     5249999.0
# 95     5600000.0
# 64     7000000.0
# 42     8000000.0
# Name: bonus, Length: 146, dtype: float64
# 7         MCMAHON JEFFREY
# 22         KITCHEN LOUISE
# 42        LAVORATO JOHN J
# 56     WHALLEY LAWRENCE G
# 59       DELAINEY DAVID W
# 64          LAY KENNETH L
# 72         FALLON JAMES B
# 81       BELDEN TIMOTHY N
# 95     SKILLING JEFFREY K
# 108       ALLEN PHILLIP K
# Name: names, dtype: object

# %%
for ind in set2.index:
    print(ind,data2.iloc[ind].names,data2.iloc[ind].salary,data2.iloc[ind].bonus)
##anomaly in bonus  ##POI 
                                     ##42 LAVORATO JOHN J 339288.0 8000000.0///more bonus than CEO and other on low salary
##81 BELDEN TIMOTHY N 213999.0 5249999.0
##108 ALLEN PHILLIP K 201955.0 4175000.0
##22 KITCHEN LOUISE 271442.0 3100000.0
print(ind,data2.iloc[ind].names,data2.iloc[ind].salary,data2.iloc[ind].bonus)
data2.head(10)
ind = [42,81,108,22]
lst = ['LAVORATO JOHN J','BELDEN TIMOTHY N','ALLEN PHILLIP K','KITCHEN LOUISE']
ind = [22,42,81,108] 
lst = ['KITCHEN LOUISE','LAVORATO JOHN J','BELDEN TIMOTHY N','ALLEN PHILLIP K']
              
# create Pandas Series with define indexes
setBonus = pd.Series(lst, index = ind)
setBonus
# Out:
# 7 MCMAHON JEFFREY 370448.0 2600000.0
# 22 KITCHEN LOUISE 271442.0 3100000.0
# 42 LAVORATO JOHN J 339288.0 8000000.0
# 56 WHALLEY LAWRENCE G 510364.0 3000000.0
# 59 DELAINEY DAVID W 365163.0 3000000.0
# 64 LAY KENNETH L 1072321.0 7000000.0
# 72 FALLON JAMES B 304588.0 2500000.0
# 81 BELDEN TIMOTHY N 213999.0 5249999.0
# 95 SKILLING JEFFREY K 1111258.0 5600000.0
# 108 ALLEN PHILLIP K 201955.0 4175000.0
# 108 ALLEN PHILLIP K 201955.0 4175000.0
# 22       KITCHEN LOUISE
# 42      LAVORATO JOHN J
# 81     BELDEN TIMOTHY N
# 108     ALLEN PHILLIP K
# dtype: object

# %%
inters = set(set1).intersection(set(set2))
inters
#Common in outliers
# Out:
# {'BELDEN TIMOTHY N',
#  'KITCHEN LOUISE',
#  'LAVORATO JOHN J',
#  'LAY KENNETH L',
#  'WHALLEY LAWRENCE G'}

# %%
set(inters).intersection(set(set0))
#POI
# Out:
# {'LAY KENNETH L'}

# %%
data2.boxplot(column =['from_this_person_to_poi'])
print(data2['from_this_person_to_poi'].sort_values())
set3 = data2[data2['from_this_person_to_poi']>100].names
set3
# Out:
# 48       0.0
# 69       0.0
# 68       0.0
# 111      0.0
# 65       0.0
#        ...
# 57     194.0
# 32     386.0
# 102    387.0
# 42     411.0
# 59     609.0
# Name: from_this_person_to_poi, Length: 146, dtype: float64
# 22          KITCHEN LOUISE
# 32            BECK SALLY W
# 42         LAVORATO JOHN J
# 57     MCCONNELL MICHAEL S
# 59        DELAINEY DAVID W
# 81        BELDEN TIMOTHY N
# 89     KAMINSKI WINCENTY J
# 102          KEAN STEVEN J
# Name: names, dtype: object

# %%
data2.boxplot(column =['from_poi_to_this_person'])
print(data2['from_poi_to_this_person'].sort_values())
set6 = data2[data2['from_poi_to_this_person']>100].names
set6
# Out:
# 131      0.0
# 69       0.0
# 68       0.0
# 65       0.0
# 63       0.0
#        ...
# 16     240.0
# 128    242.0
# 22     251.0
# 126    305.0
# 42     528.0
# Name: from_poi_to_this_person, Length: 146, dtype: float64
# 8           HAEDICKE MARK E
# 16           COLWELL WESLEY
# 22           KITCHEN LOUISE
# 32             BECK SALLY W
# 42          LAVORATO JOHN J
# 54         DEFFNER JOSEPH M
# 56       WHALLEY LAWRENCE G
# 64            LAY KENNETH L
# 75       BOWEN JR RAYMOND M
# 79          REDMOND BRIAN L
# 81         BELDEN TIMOTHY N
# 83          DURAN WILLIAM D
# 87     CALGER CHRISTOPHER F
# 102           KEAN STEVEN J
# 126        DIETRICH JANET R
# 128          FREVERT MARK A
# 140           BUY RICHARD B
# 144    DONAHUE JR JEFFREY M
# Name: names, dtype: object

# %%
setPOI = set(set3).intersection(set(set6))
print(setPOI)
                                                       ## POI: 'LAVORATO JOHN J'
##// a huge number of mails sent and recieved  in comparison to others
# Out:
# {'BECK SALLY W', 'KITCHEN LOUISE', 'KEAN STEVEN J', 'LAVORATO JOHN J', 'BELDEN TIMOTHY N'}

# %%
print(set(set2).intersection(set(set3)))
set(inters).intersection(set(set3))
##'from_this_person_to_poi' and anomaly in bonus
# Out:
# {'BELDEN TIMOTHY N', 'KITCHEN LOUISE', 'DELAINEY DAVID W', 'LAVORATO JOHN J'}
# {'BELDEN TIMOTHY N', 'KITCHEN LOUISE', 'LAVORATO JOHN J'}

# %%
data2.boxplot(column =['total_stock_value'])
print(data2['total_stock_value'].sort_values())
set4 = data2[data2['total_stock_value']>10000000].names
print(set4)
for ind in set4.index:
    print(ind,data2.iloc[ind].names,data2.iloc[ind].salary, data2.iloc[ind].total_stock_value)
# Out:
# 24       -44093.0
# 23            0.0
# 111           0.0
# 26            0.0
# 28            0.0
#           ...
# 88     22542539.0
# 129    23817930.0
# 95     26093672.0
# 125    30766064.0
# 64     49110078.0
# Name: total_stock_value, Length: 146, dtype: float64
# 1           BAXTER JOHN C
# 64          LAY KENNETH L
# 88         RICE KENNETH D
# 95     SKILLING JEFFREY K
# 106     WHITE JR THOMAS E
# 124        YEAGER F SCOTT
# 125          HIRKO JOSEPH
# 128        FREVERT MARK A
# 129             PAI LOU L
# Name: names, dtype: object
# 1 BAXTER JOHN C 267102.0 10623258.0
# 64 LAY KENNETH L 1072321.0 49110078.0
# 88 RICE KENNETH D 420636.0 22542539.0
# 95 SKILLING JEFFREY K 1111258.0 26093672.0
# 106 WHITE JR THOMAS E 317543.0 15144123.0
# 124 YEAGER F SCOTT 158403.0 11884758.0
# 125 HIRKO JOSEPH 0.0 30766064.0
# 128 FREVERT MARK A 1060932.0 14622185.0
# 129 PAI LOU L 261879.0 23817930.0

# %%
##POI:  64 LAY KENNETH L : Highest stock 
       #125 HIRKO JOSEPH 0.0 30766064.0
      #95 SKILLING JEFFREY K 1111258.0 26093672.0
                                                        #129 PAI LOU L 261879.0 23817930.0             ##less salary High stock
        #88 RICE KENNETH D 420636.0 22542539.0

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data2.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,12))
mask = np.triu(np.ones_like(data2.corr(), dtype=np.bool))
heatmap = sns.heatmap(data2.corr(), mask=mask, vmin=-1, vmax=1, annot= True, cmap='Blues')

# %%
data.info()
#NAN Checked
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   names                      146 non-null    object
#  1   salary                     146 non-null    float64
#  2   to_messages                146 non-null    float64
#  3   deferral_payments          146 non-null    float64
#  4   total_payments             146 non-null    float64
#  5   loan_advances              146 non-null    float64
#  6   bonus                      146 non-null    float64
#  7   restricted_stock_deferred  146 non-null    float64
#  8   deferred_income            146 non-null    float64
#  9   total_stock_value          146 non-null    float64
#  10  expenses                   146 non-null    float64
#  11  from_poi_to_this_person    146 non-null    float64
#  12  exercised_stock_options    146 non-null    float64
# ...

# %%
data.describe()
# Out:
#              salary   to_messages  deferral_payments  total_payments  \
# count  1.460000e+02    146.000000       1.460000e+02    1.460000e+02
# mean   3.658114e+05   1221.589041       4.387965e+05    4.350622e+06
# std    2.203575e+06   2226.770637       2.741325e+06    2.693448e+07
# min    0.000000e+00      0.000000      -1.025000e+05    0.000000e+00
# 25%    0.000000e+00      0.000000       0.000000e+00    9.394475e+04
# 50%    2.105960e+05    289.000000       0.000000e+00    9.413595e+05
# 75%    2.708505e+05   1585.750000       9.684500e+03    1.968287e+06
# max    2.670423e+07  15149.000000       3.208340e+07    3.098866e+08
#
#        loan_advances         bonus  restricted_stock_deferred  \
# count   1.460000e+02  1.460000e+02               1.460000e+02
# mean    1.149658e+06  1.333474e+06               2.051637e+04
# std     9.649342e+06  8.094029e+06               1.439661e+06
# min     0.000000e+00  0.000000e+00              -7.576788e+06
# ...

# %%
data.columns
# Out:
# Index(['names', 'salary', 'to_messages', 'deferral_payments', 'total_payments',
#        'loan_advances', 'bonus', 'restricted_stock_deferred',
#        'deferred_income', 'total_stock_value', 'expenses',
#        'from_poi_to_this_person', 'exercised_stock_options', 'from_messages',
#        'other', 'from_this_person_to_poi', 'long_term_incentive',
#        'shared_receipt_with_poi', 'restricted_stock', 'director_fees',
#        'email_address'],
#       dtype='object')

# %%
sns.scatterplot(data2['salary'], data2['bonus'])
data2[data2['bonus']>3000000]
# Out:
# C:\Users\Himanshu Rajpoot\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#                   names     salary  to_messages  deferral_payments  \
# 22       KITCHEN LOUISE   271442.0       8305.0                0.0
# 42      LAVORATO JOHN J   339288.0       7259.0                0.0
# 64        LAY KENNETH L  1072321.0       4273.0           202911.0
# 81     BELDEN TIMOTHY N   213999.0       7991.0          2144013.0
# 95   SKILLING JEFFREY K  1111258.0       3627.0                0.0
# 108     ALLEN PHILLIP K   201955.0       2902.0          2869717.0
#
#      total_payments  loan_advances      bonus  restricted_stock_deferred  \
# 22        3471141.0            0.0  3100000.0                        0.0
# ...

# %%
sns.scatterplot(data2['salary'], data2['total_stock_value'])
data2[data2['total_stock_value']>30000000]
# Out:
# C:\Users\Himanshu Rajpoot\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#              names     salary  to_messages  deferral_payments  total_payments  \
# 64   LAY KENNETH L  1072321.0       4273.0           202911.0     103559793.0
# 125   HIRKO JOSEPH        0.0          0.0            10259.0         91093.0
#
#      loan_advances      bonus  restricted_stock_deferred  deferred_income  \
# 64      81525000.0  7000000.0                        0.0        -300000.0
# 125            0.0        0.0                        0.0              0.0
#
#      total_stock_value  ...  from_poi_to_this_person  exercised_stock_options  \
# 64          49110078.0  ...                    123.0               34348384.0
# ...

# %%
data2[data2['total_stock_value']>20000000]
# Out:
#                   names     salary  to_messages  deferral_payments  \
# 64        LAY KENNETH L  1072321.0       4273.0           202911.0
# 88       RICE KENNETH D   420636.0        905.0                0.0
# 95   SKILLING JEFFREY K  1111258.0       3627.0                0.0
# 125        HIRKO JOSEPH        0.0          0.0            10259.0
# 129           PAI LOU L   261879.0          0.0                0.0
#
#      total_payments  loan_advances      bonus  restricted_stock_deferred  \
# 64      103559793.0     81525000.0  7000000.0                        0.0
# 88         505050.0            0.0  1750000.0                        0.0
# 95        8682716.0            0.0  5600000.0                        0.0
# 125         91093.0            0.0        0.0                        0.0
# 129       3123383.0            0.0  1000000.0                        0.0
#
#      deferred_income  total_stock_value  ...  from_poi_to_this_person  \
# ...

# %%
 #POI
 ##highest mail sent and received:                                   'KEAN STEVEN J'--------

##more bonus than CEO and on low salary,
#huge number of mails sent and recieved                               'LAVORATO JOHN J'---------

##Highest stock                                                        'LAY KENNETH L'++++++++
#less salary High stock                                               *'PAI LOU L'          --------
#                                                                     'RICE KENNETH D'       +++++++++
#https://www.npr.org/templates/story/story.php?storyId=5411422
## 2ndHighest stock                                                  *'HIRKO JOSEPH'       ++++++++++++
# https://www.nytimes.com/2009/09/29/business/29enron.html
#high salary,bonus,3rd highest stock                                'SKILLING JEFFREY K' ++++++++++++++++

#4th person with huge bonus and low salary                          'BELDEN TIMOTHY N'  ++++++++++++
#5th person with huge bonus and low salary                          'ALLEN PHILLIP K'    --------------

# %%
print(set4)
print(setPOI)
print(setBonus)
print(setMsg)
# Out:
# 1           BAXTER JOHN C
# 64          LAY KENNETH L
# 88         RICE KENNETH D
# 95     SKILLING JEFFREY K
# 106     WHITE JR THOMAS E
# 124        YEAGER F SCOTT
# 125          HIRKO JOSEPH
# 128        FREVERT MARK A
# 129             PAI LOU L
# Name: names, dtype: object
# {'BECK SALLY W', 'KITCHEN LOUISE', 'KEAN STEVEN J', 'LAVORATO JOHN J', 'BELDEN TIMOTHY N'}
# 22       KITCHEN LOUISE
# 42      LAVORATO JOHN J
# 81     BELDEN TIMOTHY N
# 108     ALLEN PHILLIP K
# dtype: object
# {'BECK SALLY W', 'KEAN STEVEN J', 'LAVORATO JOHN J', 'KAMINSKI WINCENTY J'}
